# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heart (1).csv")

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
# Data cleanning already happend

# %% [markdown]
# ## full meaning of columns
#
#
# Sex : Sex of the patient
#
# exang: exercise induced angina (1 = yes; 0 = no)
#
# trtbps : resting blood pressure (in mm Hg)
#
# ca: number of major vessels (0-3)
#
# cp : Chest Pain type
#
# chol : cholestoral in mg/dl fetched via BMI sensor
#
# fbs : (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#
# rest_ecg : resting electrocardiographic results
#
# thalach : maximum heart rate achieved
#
# target : 0= less chance of heart attack 1= more chance of heart attack

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df= df.rename(columns={'trtbps':"blood_Pres"})

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'blood_Pres', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df= df.rename(columns={"exng":"exersize"})

# %%
df.head()
# Out:
#    age  sex  cp  blood_Pres  chol  fbs  restecg  thalachh  exersize  oldpeak  \
# 0   63    1   3         145   233    1        0       150         0      2.3
# 1   37    1   2         130   250    0        1       187         0      3.5
# 2   41    0   1         130   204    0        0       172         0      1.4
# 3   56    1   1         120   236    0        1       178         0      0.8
# 4   57    0   0         120   354    0        1       163         1      0.6
#
#    slp  caa  thall  output
# 0    0    0      1       1
# 1    0    0      2       1
# 2    2    0      2       1
# 3    2    0      2       1
# 4    2    0      2       1

# %%
df = df.rename(columns={"thalachh":"Heart_rate"})

# %%
df.head()
# Out:
#    age  sex  cp  blood_Pres  chol  fbs  restecg  Heart_rate  exersize  \
# 0   63    1   3         145   233    1        0         150         0
# 1   37    1   2         130   250    0        1         187         0
# 2   41    0   1         130   204    0        0         172         0
# 3   56    1   1         120   236    0        1         178         0
# 4   57    0   0         120   354    0        1         163         1
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1
# 3      0.8    2    0      2       1
# 4      0.6    2    0      2       1

# %%
print(f"no of rows =",df.shape[0])
# Out:
# no of rows = 303

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         303 non-null    int64
#  1   sex         303 non-null    int64
#  2   cp          303 non-null    int64
#  3   blood_Pres  303 non-null    int64
#  4   chol        303 non-null    int64
#  5   fbs         303 non-null    int64
#  6   restecg     303 non-null    int64
#  7   Heart_rate  303 non-null    int64
#  8   exersize    303 non-null    int64
#  9   oldpeak     303 non-null    float64
#  10  slp         303 non-null    int64
#  11  caa         303 non-null    int64
#  12  thall       303 non-null    int64
#  13  output      303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.head(3)
# Out:
#    age  sex  cp  blood_Pres  chol  fbs  restecg  Heart_rate  exersize  \
# 0   63    1   3         145   233    1        0         150         0
# 1   37    1   2         130   250    0        1         187         0
# 2   41    0   1         130   204    0        0         172         0
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1

# %%
sns.barplot(x="cp", y="output",data=df)
plt.xlabel('CP')
# Out:
# Text(0.5, 0, 'CP')

# %%
sns.set_context('notebook', font_scale= 2)
fig, ax = plt.subplots(2, 2, figsize = (20, 13))

plt.suptitle('Distribution of various features based on target variable', fontsize = 20)

ax1 = sns.histplot(x ='age', data= df, hue= 'output', kde= True, ax= ax[0, 0], palette='winter')
ax2= sns.histplot(x='cp',hue='output', data= df,ax=ax[0,1],kde=True)
ax3= sns.histplot(x='blood_Pres', data= df, kde= True, ax= ax[1,0],hue="output")
ax4 = sns.histplot(x='Heart_rate', hue='output',data= df)

# %% [markdown]
# ### from the above histplot we can say that person having high heart rate most likely for the heart attack.

# %%
df.exersize.value_counts()
# Out:
# 0    204
# 1     99
# Name: exersize, dtype: int64

# %%
df.head(3)
# Out:
#    age  sex  cp  blood_Pres  chol  fbs  restecg  Heart_rate  exersize  \
# 0   63    1   3         145   233    1        0         150         0
# 1   37    1   2         130   250    0        1         187         0
# 2   41    0   1         130   204    0        0         172         0
#
#    oldpeak  slp  caa  thall  output
# 0      2.3    0    0      1       1
# 1      3.5    0    0      2       1
# 2      1.4    2    0      2       1

# %%
sns.histplot(x="age", hue='output', data= df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='age',hue='output', data= df,kde=True)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='blood_Pres',hue='output', data= df,kde=True)
plt.plot()
# Out:
# []

# %%
sns.boxplot(x=df.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Now same things in the boxplot

# %%
sns.set_context("notebook", font_scale=1.2)
fig, ax = plt.subplots(2,2 , figsize=(13,10))

ax1 = sns.boxplot(x='blood_Pres',data= df ,ax= ax[0,0])
ax1 = sns.boxplot(x='age',data= df ,ax= ax[0,1])
ax1 = sns.boxplot(x='Heart_rate',data= df ,ax= ax[1,0])
ax1 = sns.boxplot(x='chol',data= df ,ax= ax[1,1])

# %%
sns.histplot(df.age,kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df.age.describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.boxplot(df.age)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ## Now time for Heatmap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,fmt="0.2f")
plt.plot()
# Out:
# []

# %%
plt.pie(df.output.value_counts(),explode=[0.1,0.1],autopct="%0.2f%%")
plt.plot()
# Out:
# []

# %%
df.output.value_counts()
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64

# %%
df.output.value_counts().plot(kind="pie",autopct="%0.2f%%",explode=[0.1,0.1])
# Out:
# <AxesSubplot:ylabel='output'>

# %% [markdown]
# ### This is our simple visualization
